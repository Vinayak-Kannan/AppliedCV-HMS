# %%
# !mkdir gcs
# !gcsfuse --implicit-dirs --rename-dir-limit=100 --max-conns-per-host=100 "hms_applied_cv" "/home/jupyter/data"
# Out:
# {"time":"15/04/2024 04:45:58.534355","severity":"INFO","message":"Start gcsfuse/2.0.0 (Go version go1.22.1) for app \"\" using mount point: /home/jupyter/data\n"}
# {"time":"15/04/2024 04:45:58.534592","severity":"INFO","message":"GCSFuse mount command flags: {\"AppName\":\"\",\"Foreground\":false,\"ConfigFile\":\"\",\"MountOptions\":{},\"DirMode\":493,\"FileMode\":420,\"Uid\":-1,\"Gid\":-1,\"ImplicitDirs\":true,\"OnlyDir\":\"\",\"RenameDirLimit\":100,\"CustomEndpoint\":null,\"BillingProject\":\"\",\"KeyFile\":\"\",\"TokenUrl\":\"\",\"ReuseTokenFromUrl\":true,\"EgressBandwidthLimitBytesPerSecond\":-1,\"OpRateLimitHz\":-1,\"SequentialReadSizeMb\":200,\"MaxRetrySleep\":30000000000,\"StatCacheCapacity\":20460,\"StatCacheTTL\":60000000000,\"TypeCacheTTL\":60000000000,\"HttpClientTimeout\":0,\"MaxRetryDuration\":-1000000000,\"RetryMultiplier\":2,\"LocalFileCache\":false,\"TempDir\":\"\",\"ClientProtocol\":\"http1\",\"MaxConnsPerHost\":100,\"MaxIdleConnsPerHost\":100,\"EnableNonexistentTypeCache\":false,\"StackdriverExportInterval\":0,\"OtelCollectorAddress\":\"\",\"LogFile\":\"\",\"LogFormat\":\"json\",\"ExperimentalEnableJsonRead\":false,\"DebugFuseErrors\":true,\"DebugFuse\":false,\"DebugFS\":false,\"DebugGCS\":false,\"DebugHTTP\":false,\"DebugInvariants\":false,\"DebugMutex\":false}"}
# {"time":"15/04/2024 04:45:58.534685","severity":"INFO","message":"GCSFuse mount config flags: {\"CreateEmptyFile\":false,\"Severity\":\"INFO\",\"Format\":\"json\",\"FilePath\":\"\",\"LogRotateConfig\":{\"MaxFileSizeMB\":512,\"BackupFileCount\":10,\"Compress\":true},\"MaxSizeMB\":-1,\"CacheFileForRangeRead\":false,\"CacheDir\":\"\",\"TtlInSeconds\":-9223372036854775808,\"TypeCacheMaxSizeMB\":4,\"StatCacheMaxSizeMB\":-9223372036854775808,\"EnableEmptyManagedFolders\":false}"}
# {"time":"15/04/2024 04:45:58.717153","severity":"INFO","message":"File system has been successfully mounted."}

# %%
# ! pip install sktime
! pip install sktime[all_extras]
! pip install sktime[mlflow]
# Out:
# Requirement already satisfied: sktime[all_extras] in /opt/conda/lib/python3.10/site-packages (0.28.0)
# WARNING: sktime 0.28.0 does not provide the extra 'all-extras'
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (23.2)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2.1.4)
# Requirement already satisfied: scikit-base<0.8.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.7.5)
# Requirement already satisfied: scikit-learn<1.5.0,>=0.24 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.4.1.post1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.11.4)
# Requirement already satisfied: arch<6.4.0,>=5.6 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (6.3.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (3.0.0)
# Requirement already satisfied: dash!=2.9.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2.16.1)
# Requirement already satisfied: dask<2024.2.2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2024.2.1)
# Requirement already satisfied: dtw-python in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.4.2)
# Requirement already satisfied: gluonts>=0.9 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.14.4)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.46)
# Requirement already satisfied: kotsu>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.3.3)
# Requirement already satisfied: matplotlib>=3.3.2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (3.8.3)
# Requirement already satisfied: mne in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.6.1)
# Requirement already satisfied: numba<0.60,>=0.53 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.59.1)
# Requirement already satisfied: pycatch22<0.4.4 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.4.2)
# Requirement already satisfied: pykalman<0.10,>=0.9.5 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.9.7)
# Requirement already satisfied: scikit-optimize in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.10.1)
# Requirement already satisfied: scikit-posthocs>=0.6.5 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.9.0)
# Requirement already satisfied: seaborn>=0.11 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.12.2)
# Requirement already satisfied: seasonal in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.3.1)
# Requirement already satisfied: skpro<2.3.0,>=2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2.2.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.14.1)
# Requirement already satisfied: tsbootstrap<0.2,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.1.0)
# Requirement already satisfied: xarray in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2024.3.0)
# Requirement already satisfied: filterpy>=1.4.5 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.4.5)
# Requirement already satisfied: hmmlearn>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.3.2)
# Requirement already satisfied: keras-self-attention in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.51.0)
# Requirement already satisfied: pyod>=0.8 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.1.3)
# Requirement already satisfied: stumpy>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.12.0)
# Requirement already satisfied: tslearn!=0.6.0,<0.7.0,>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.6.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (3.10.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2.0.4)
# Requirement already satisfied: prophet>=1.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.1.5)
# Requirement already satisfied: pyts<0.14.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.13.0)
# Requirement already satisfied: statsforecast<1.8.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.7.4)
# Requirement already satisfied: tbats>=1.1 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (1.1.3)
# Requirement already satisfied: tensorflow<2.17,>=2 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (2.16.1)
# Requirement already satisfied: tsfresh>=0.17 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.20.2)
# Requirement already satisfied: temporian!=0.8.0,<0.9.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from sktime[all_extras]) (0.8.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (3.0.2)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (5.20.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (5.0.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (6.11.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (4.10.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (2.31.0)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (69.2.0)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.10/site-packages (from dask<2024.2.2->sktime[all_extras]) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.10/site-packages (from dask<2024.2.2->sktime[all_extras]) (2024.3.1)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from dask<2024.2.2->sktime[all_extras]) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from dask<2024.2.2->sktime[all_extras]) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from dask<2024.2.2->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: pydantic<3,>=1.7 in /opt/conda/lib/python3.10/site-packages (from gluonts>=0.9->sktime[all_extras]) (2.6.4)
# Requirement already satisfied: tqdm~=4.23 in /opt/conda/lib/python3.10/site-packages (from gluonts>=0.9->sktime[all_extras]) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.9.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba<0.60,>=0.53->sktime[all_extras]) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=1.1->sktime[all_extras]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=1.1->sktime[all_extras]) (2024.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8->sktime[all_extras]) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8->sktime[all_extras]) (3.0.10)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8->sktime[all_extras]) (1.26.18)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/conda/lib/python3.10/site-packages (from prophet>=1.1->sktime[all_extras]) (1.2.2)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from prophet>=1.1->sktime[all_extras]) (6.3.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from pyod>=0.8->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.5.0,>=0.24->sktime[all_extras]) (3.3.0)
# Requirement already satisfied: coreforecast>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.0.7)
# Requirement already satisfied: fugue>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.8.7)
# Requirement already satisfied: utilsforecast>=0.0.24 in /opt/conda/lib/python3.10/site-packages (from statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.1.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.6)
# Requirement already satisfied: absl-py<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from temporian!=0.8.0,<0.9.0,>=0.7.0->sktime[all_extras]) (1.4.0)
# Requirement already satisfied: protobuf>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from temporian!=0.8.0,<0.9.0,>=0.7.0->sktime[all_extras]) (3.20.3)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.17,>=2->sktime[all_extras]) (0.36.0)
# Requirement already satisfied: pooch>=1.5 in /opt/conda/lib/python3.10/site-packages (from mne->sktime[all_extras]) (1.8.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from mne->sktime[all_extras]) (5.1.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mne->sktime[all_extras]) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from mne->sktime[all_extras]) (0.3)
# Requirement already satisfied: pyaml>=16.9 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize->sktime[all_extras]) (23.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2->sktime[all_extras]) (0.42.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from cmdstanpy>=1.0.4->prophet>=1.1->sktime[all_extras]) (0.5.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (1.7.0)
# Requirement already satisfied: triad>=0.9.3 in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.9.6)
# Requirement already satisfied: adagio>=0.2.4 in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: sqlglot in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (23.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->dash!=2.9.0->sktime[all_extras]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->mne->sktime[all_extras]) (2.1.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (0.0.7)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (0.11.0)
# Requirement already satisfied: locket in /opt/conda/lib/python3.10/site-packages (from partd>=1.2.0->dask<2024.2.2->sktime[all_extras]) (1.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=5.0.0->dash!=2.9.0->sktime[all_extras]) (8.2.3)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne->sktime[all_extras]) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts>=0.9->sktime[all_extras]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts>=0.9->sktime[all_extras]) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2->sktime[all_extras]) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2->sktime[all_extras]) (0.7.2)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in /opt/conda/lib/python3.10/site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (4.11.1)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (15.0.2)
# Requirement already satisfied: fs in /opt/conda/lib/python3.10/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (2.4.16)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2->sktime[all_extras]) (0.1.2)
# Requirement already satisfied: appdirs~=1.4.3 in /opt/conda/lib/python3.10/site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (1.4.4)
# Requirement already satisfied: sktime[mlflow] in /opt/conda/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (23.2)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (2.1.4)
# Requirement already satisfied: scikit-base<0.8.0 in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (0.7.5)
# Requirement already satisfied: scikit-learn<1.5.0,>=0.24 in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (1.4.1.post1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (1.11.4)
# Requirement already satisfied: mlflow in /opt/conda/lib/python3.10/site-packages (from sktime[mlflow]) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=1.1->sktime[mlflow]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=1.1->sktime[mlflow]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=1.1->sktime[mlflow]) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.5.0,>=0.24->sktime[mlflow]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.5.0,>=0.24->sktime[mlflow]) (3.3.0)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.0.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.1.42)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.20.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (2.31.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (6.11.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (7.0.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.0.3)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (2.0.28)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (15.0.2)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.6)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.8.3)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.3)
# Requirement already satisfied: gunicorn<22 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (21.2.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow->sktime[mlflow]) (3.1.3)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow->sktime[mlflow]) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow->sktime[mlflow]) (4.10.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow->sktime[mlflow]) (1.26.18)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow->sktime[mlflow]) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow->sktime[mlflow]) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow->sktime[mlflow]) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow->sktime[mlflow]) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow->sktime[mlflow]) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow->sktime[mlflow]) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow->sktime[mlflow]) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow->sktime[mlflow]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow->sktime[mlflow]) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow->sktime[mlflow]) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime[mlflow]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow->sktime[mlflow]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow->sktime[mlflow]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow->sktime[mlflow]) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow->sktime[mlflow]) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow->sktime[mlflow]) (5.0.1)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import joblib
import sktime
from sktime.classification.deep_learning import CNNClassifier, LSTMFCNClassifier
from sktime.classification.kernel_based import Arsenal
from sklearn.preprocessing import OneHotEncoder
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
from sktime.forecasting.arima import ARIMA
from sktime.classification.distance_based import KNeighborsTimeSeriesClassifier
from sktime.utils import mlflow_sktime
from sktime.classification.kernel_based import RocketClassifier
import pickle

# %%
mlflow_sktime.save_model
# Out:
# <function sktime.utils.mlflow_sktime.save_model(sktime_model, path, conda_env=None, code_paths=None, mlflow_model=None, signature=None, input_example=None, pip_requirements=None, extra_pip_requirements=None, serialization_format='pickle')>

# %%
features = pd.read_csv('data/hms-harmful-brain-activity-classification/cleaned_train.csv')

# %%
features.columns
# Out:
# Index(['Unnamed: 0', 'eeg_id', 'eeg_sub_id', 'eeg_label_offset_seconds',
#        'spectrogram_id', 'spectrogram_sub_id',
#        'spectrogram_label_offset_seconds', 'label_id', 'patient_id',
#        'expert_consensus', 'seizure_vote', 'lpd_vote', 'gpd_vote', 'lrda_vote',
#        'grda_vote', 'other_vote', 'concatenated_scores', 'is_center'],
#       dtype='object')

# %%
len(features)
# Out:
# 106800

# %%
train_size = 20000 # 1000
val_size = 6000 # 200

actual_train = 0
actual_val = 0

train_ind = features.iloc[:train_size]['eeg_id']
val_ind = features.iloc[train_size:val_size + train_size]['eeg_id']

x_train = []
y_train = []

x_val = []
y_val = []


for i in range(0,train_size):
    ind = features.iloc[i]['eeg_id']
    pq = pd.read_parquet(f"data/hms-harmful-brain-activity-classification/train_eegs/{ind}.parquet")
    middle = (len(pq)-2_000)//2
    pq = pq.iloc[middle:middle+2_000:2]
    pq = pq.reset_index()
    x_train.append(pq)
    y_train.append(features.iloc[i]['expert_consensus'])
    
    
for i in range(train_size, val_size + train_size):
    ind = features.iloc[i]['eeg_id']
    pq = pd.read_parquet(f"data/hms-harmful-brain-activity-classification/train_eegs/{ind}.parquet")
    middle = (len(pq)-2_000)//2
    pq = pq.iloc[middle:middle+2_000:2]
    pq = pq.reset_index()
    x_val.append(pq)
    y_val.append(features.iloc[i]['expert_consensus'])
    
x_train = pd.concat(x_train,keys=list(range(train_size)),axis=0).reset_index(level=1)
x_train['instances'] = x_train.index
x_train = x_train.rename(columns={"level_1": "timepoints"})
x_train = x_train.set_index(['instances', 'timepoints'])
x_train = x_train.fillna(0)


x_val = pd.concat(x_val,keys=list(range(val_size)),axis=0).reset_index(level=1)
x_val['instances'] = x_val.index
x_val = x_val.rename(columns={"level_1": "timepoints"})
x_val = x_val.set_index(['instances', 'timepoints'])
x_val = x_val.fillna(0)


y_train = pd.get_dummies(y_train, columns = ['GPD','GRDA','LPD','LRDA','Other','Seizure']).astype("int32")
y_train = y_train.reset_index(drop=True)

y_val = pd.get_dummies(y_val, columns = ['GPD','GRDA','LPD','LRDA','Other','Seizure']).astype("int32")
y_val = y_val.reset_index(drop=True)

# %%
x_train.to_csv("/home/jupyter/x_train.csv")
x_val.to_csv("/home/jupyter/x_val.csv")

y_train.to_csv("/home/jupyter/y_train.csv")
y_val.to_csv("/home/jupyter/y_val.csv")

# %%
x_train = pd.read_csv("/home/jupyter/x_train.csv")
x_val = pd.read_csv("/home/jupyter/x_val.csv")

# %%
x_train = x_train.set_index(['instances', 'timepoints'])
x_val = x_val.set_index(['instances', 'timepoints'])
y

# %%
y_train = pd.read_csv("/home/jupyter/y_train.csv", index_col=0)
y_val = pd.read_csv("/home/jupyter/y_val.csv", index_col=0)

# %%
x_train[:1000*1000]
# Out:
#                       index    Fp1      F3      C3      P3      F7      T3  \
# instances timepoints
# 0         0            5600  50.14  125.69  273.30  210.12  151.85  125.79
#           1            5602  14.41   70.96  223.35  171.77  102.79   78.21
#           2            5604  22.87   80.81  254.64  203.74  125.33   99.74
#           3            5606  19.78   59.58  230.42  187.28  108.51   86.94
#           4            5608 -14.46   26.90  217.55  169.16   82.12   67.85
# ...                     ...    ...     ...     ...     ...     ...     ...
# 999       995          8790 -42.27  -53.97  -21.00  -29.77  -45.46  -11.17
#           996          8792 -49.45  -65.40  -34.82  -42.00  -60.08  -22.06
#           997          8794 -29.24  -48.38  -23.13  -30.84  -41.20   -7.44
#           998          8796 -45.72  -61.14  -42.00  -54.23  -58.48  -24.46
#           999          8798 -16.75  -30.04  -17.28  -33.76  -29.77    0.53
#
#                           T5      O1     Fz  ...     Pz     Fp2      F4  \
# instances timepoints                         ...
# 0         0           239.60  250.11  54.24  ...  67.80  108.64  190.89
#           1           202.62  209.94   6.84  ...  22.05   73.74  145.24
#           2           222.63  234.26  19.97  ...  66.29   93.04  169.55
#           3           209.18  221.25   6.53  ...  50.27   99.64  156.97
#           4           194.67  200.64 -24.83  ...  41.47   76.15  136.82
# ...                      ...     ...    ...  ...    ...     ...     ...
# 999       995         -31.90  -19.67 -27.12  ... -18.08   -7.71   -9.04
#           996         -43.33  -31.90 -35.62  ... -28.44  -17.81  -21.00
#           997         -30.84  -24.99 -17.01  ... -16.48    0.27   -9.30
#           998         -56.36  -48.38 -35.09  ... -36.42  -19.14  -14.89
#           999         -37.48  -35.09 -10.37  ... -14.89    3.99  -10.37
#
#                           C4      P4     F8      T4      T6      O2       EKG
# instances timepoints
# 0         0            92.96  302.47  35.88  332.87  155.05  135.88  32855.60
#           1            59.31  259.79  -9.09  290.35  146.31   89.02    751.12
#           2           106.53  356.57  21.58  350.74  192.74  119.76    308.50
#           3           104.67  302.20   6.66  309.80  198.64  102.93  -3342.34
#           4            96.47  355.69  -7.12  314.93  194.51   83.54   3232.94
# ...                      ...     ...    ...     ...     ...     ...       ...
# 999       995         -43.33    8.24 -36.42  -22.60  -32.96   -8.51     -0.27
#           996         -51.84   -8.24 -46.79  -39.34  -53.43  -24.46      1.33
#           997         -38.28   36.42 -32.43    5.05   -3.72   21.00      0.53
#           998         -52.90  -16.75 -45.72  -45.72  -59.28  -28.44     -0.80
#           999         -33.50   42.00 -30.57   11.17    0.00   29.51      0.79
#
# [1000000 rows x 21 columns]

# %%
 # Fit and save model
model = RocketClassifier(num_kernels=5000)
predictions = model.fit(x_train[:5000*1000], y_train[:5000])
mlflow_sktime.save_model(model, "/home/jupyter/rocket")

# %%
with open('rocket.pkl','wb') as f:
    pickle.dump(model,f)

# %%
# Predict and print accuracy
predictions = model.predict(x_val[:1000*1000])

# %%
predictions.idxmax(axis=1)
# Out:
# 0      Seizure
# 1      Seizure
# 2      Seizure
# 3      Seizure
# 4      Seizure
#         ...
# 995      Other
# 996        GPD
# 997        GPD
# 998        GPD
# 999        GPD
# Length: 1000, dtype: object

# %%
print(accuracy_score(y_val.idxmax(axis=1)[:1000],predictions.idxmax(axis=1) ))
# Out:
# 0.243

# %%
pd.get_dummies(y_val)
# Out:
#     LPD
# 0  True
# 1  True

# %%
eeg_id = features.iloc[1]['eeg_id']
label = features.iloc[1]['expert_consensus']

pq = pd.read_parquet(f"gcs/hms-harmful-brain-activity-classification/train_eegs/{eeg_id}.parquet")
middle = (len(pq)-10_000)//2
pq = pq.iloc[middle:middle+10_000]
pq1 = pq.reset_index()

# %%
eeg_id = features.iloc[2]['eeg_id']
label2 = features.iloc[2]['expert_consensus']

pq = pd.read_parquet(f"gcs/hms-harmful-brain-activity-classification/train_eegs/{eeg_id}.parquet")
middle = (len(pq)-10_000)//2
pq = pq.iloc[middle:middle+10_000]
pq2 = pq.reset_index()

# %%
mi_pd = pd.concat([pq1,pq2],keys= [1,2],axis=0).reset_index(level=1)

# %%
mi_pd.columns
# Out:
# Index(['level_1', 'index', 'Fp1', 'F3', 'C3', 'P3', 'F7', 'T3', 'T5', 'O1',
#        'Fz', 'Cz', 'Pz', 'Fp2', 'F4', 'C4', 'P4', 'F8', 'T4', 'T6', 'O2',
#        'EKG'],
#       dtype='object')

# %%
mi_pd
# Out:
#     level_1  index         Fp1         F3          C3          P3          F7  \
# 1         0   1600   26.139999  27.540001  114.160004   50.130001   65.769997
# 1         1   1601   -0.860000   3.940000   94.050003   28.770000   42.549999
# 1         2   1602    6.090000  -5.510000   73.160004   26.350000   41.560001
# 1         3   1603   42.860001  34.759998  112.150002   71.410004   83.809998
# 1         4   1604   27.459999  31.379999  116.540001   69.680000   75.730003
# ..      ...    ...         ...        ...         ...         ...         ...
# 2      9995  11595 -102.949997 -56.820000  135.770004  -47.740002  -87.129997
# 2      9996  11596  -99.110001 -64.269997  119.199997  -49.349998  -82.370003
# 2      9997  11597  -79.410004 -35.320000  154.639999  -23.670000  -53.520000
# 2      9998  11598 -109.790001 -59.380001  136.360001  -60.650002  -80.849998
# 2      9999  11599 -127.660004 -87.139999   98.919998 -101.410004 -105.540001
#
#             T3          T5          O1  ...         Pz         Fp2         F4  \
# 1   149.500000   38.090000   37.820000  ...  75.519997   76.720001  67.870003
# 1   119.040001   12.320000   13.630000  ...  53.720001   46.950001  44.099998
# 1   109.250000    9.220000   12.420000  ...  41.970001   48.900002  33.180000
# 1   151.070007   53.660000   56.369999  ...  89.720001   82.389999  66.529999
# 1   142.119995   49.840000   52.810001  ...  94.160004   68.110001  57.950001
# ..         ...         ...         ...  ...        ...         ...        ...
# 2   -41.790001  -77.870003 -137.360001  ... -13.450000  -69.680000 -32.099998
# 2   -47.299999  -78.370003 -129.899994  ... -24.170000  -68.099998 -36.570000
# 2   -22.360001  -52.980000  -97.040001  ...   9.870000  -48.150002  -7.770000
# 2   -59.080002  -93.790001 -131.070007  ... -21.840000  -81.470001 -29.740000
# 2   -96.019997 -131.619995 -164.020004  ... -61.590000 -101.260002 -54.610001
#
#             C4          P4          F8          T4          T6          O2  \
# 1    21.830000  204.610001  -59.549999  241.250000   87.320000  150.979996
# 1    -3.100000  212.619995  -79.680000  225.089996   68.389999  126.430000
# 1    -6.840000  162.610001  -88.129997  196.699997   67.419998  120.349998
# 1    38.090000  205.720001  -51.060001  241.250000  101.110001  165.110001
# 1    35.310001  254.679993  -52.689999  256.089996  100.150002  164.940002
# ..         ...         ...         ...         ...         ...         ...
# 2   -63.790001   22.719999 -118.230003  119.610001  -80.580002  -73.160004
# 2   -72.809998  -28.790001 -128.770004   85.580002  -82.309998  -76.040001
# 2   -44.349998   23.590000 -104.160004  114.379997  -70.300003  -49.049999
# 2   -83.830002   24.430000 -132.429993   79.720001 -112.820000  -84.279999
# 2  -118.900002  -62.160000 -166.250000   15.350000 -150.179993 -124.690002
#
#             EKG
# 1  -2648.439941
# 1   2274.139893
# 1    153.940002
# 1  -3030.659912
# 1    404.940002
# ..          ...
# 2   2372.300049
# 2    130.539993
# 2  -2685.510010
# 2   1606.150024
# 2   2170.110107
#
# [20000 rows x 22 columns]

# %%
# 80/20 split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
sktime.datatypes.mtype(mi_pd)
# Out:
# 'pd_DataFrame_Table'

# %%
sktime.datatypes.check_raise(pd.DataFrame([1,2]), mtype='pd_DataFrame_Table')
# Out:
# True

# %%
mi_pd = mi_pd.astype(object)

# %%
mi_pd['i'] = mi_pd.index

# %%
mi_pd
# Out:
#    level_1  index         Fp1         F3          C3          P3          F7  \
# 1        0   1600   26.139999  27.540001  114.160004   50.130001   65.769997
# 1        1   1601       -0.86       3.94   94.050003       28.77   42.549999
# 1        2   1602        6.09      -5.51   73.160004       26.35   41.560001
# 1        3   1603   42.860001  34.759998  112.150002   71.410004   83.809998
# 1        4   1604   27.459999  31.379999  116.540001       69.68   75.730003
# ..     ...    ...         ...        ...         ...         ...         ...
# 2     9995  11595 -102.949997     -56.82  135.770004  -47.740002  -87.129997
# 2     9996  11596  -99.110001 -64.269997  119.199997  -49.349998  -82.370003
# 2     9997  11597  -79.410004     -35.32  154.639999      -23.67      -53.52
# 2     9998  11598 -109.790001 -59.380001  136.360001  -60.650002  -80.849998
# 2     9999  11599 -127.660004 -87.139999   98.919998 -101.410004 -105.540001
#
#             T3          T5          O1  ...         Fp2         F4  \
# 1        149.5       38.09       37.82  ...   76.720001  67.870003
# 1   119.040001       12.32       13.63  ...   46.950001  44.099998
# 1       109.25        9.22       12.42  ...   48.900002      33.18
# 1   151.070007       53.66   56.369999  ...   82.389999  66.529999
# 1   142.119995       49.84   52.810001  ...   68.110001  57.950001
# ..         ...         ...         ...  ...         ...        ...
# 2   -41.790001  -77.870003 -137.360001  ...      -69.68 -32.099998
# 2   -47.299999  -78.370003 -129.899994  ...  -68.099998     -36.57
# 2   -22.360001      -52.98  -97.040001  ...  -48.150002      -7.77
# 2   -59.080002  -93.790001 -131.070007  ...  -81.470001     -29.74
# 2   -96.019997 -131.619995 -164.020004  ... -101.260002 -54.610001
#
#             C4          P4          F8          T4          T6          O2  \
# 1        21.83  204.610001  -59.549999      241.25       87.32  150.979996
# 1         -3.1  212.619995      -79.68  225.089996   68.389999      126.43
# 1        -6.84  162.610001  -88.129997  196.699997   67.419998  120.349998
# 1        38.09  205.720001  -51.060001      241.25  101.110001  165.110001
# 1    35.310001  254.679993  -52.689999  256.089996  100.150002  164.940002
# ..         ...         ...         ...         ...         ...         ...
# 2   -63.790001   22.719999 -118.230003  119.610001  -80.580002  -73.160004
# 2   -72.809998  -28.790001 -128.770004   85.580002  -82.309998  -76.040001
# 2   -44.349998       23.59 -104.160004  114.379997  -70.300003  -49.049999
# 2   -83.830002       24.43 -132.429993   79.720001     -112.82  -84.279999
# 2  -118.900002      -62.16     -166.25       15.35 -150.179993 -124.690002
#
#             EKG index1
# 1  -2648.439941      1
# 1   2274.139893      1
# 1    153.940002      1
# 1  -3030.659912      1
# 1    404.940002      1
# ..          ...    ...
# 2   2372.300049      2
# 2    130.539993      2
# 2   -2685.51001      2
# 2   1606.150024      2
# 2   2170.110107      2
#
# [20000 rows x 23 columns]

# %%
mi_pd['instances'] = mi_pd.index
mi_pd = mi_pd.rename(columns={"level_1": "timepoints"})
mi_pd = mi_pd.set_index(['instances', 'timepoints'])
# mi_pd = mi_pd.rename(columns={"index1": "instances"})

# %%
mi_pd
# Out:
#                       index         Fp1         F3          C3          P3  \
# instances timepoints
# 1         0            1600   26.139999  27.540001  114.160004   50.130001
#           1            1601   -0.860000   3.940000   94.050003   28.770000
#           2            1602    6.090000  -5.510000   73.160004   26.350000
#           3            1603   42.860001  34.759998  112.150002   71.410004
#           4            1604   27.459999  31.379999  116.540001   69.680000
# ...                     ...         ...        ...         ...         ...
# 2         9995        11595 -102.949997 -56.820000  135.770004  -47.740002
#           9996        11596  -99.110001 -64.269997  119.199997  -49.349998
#           9997        11597  -79.410004 -35.320000  154.639999  -23.670000
#           9998        11598 -109.790001 -59.380001  136.360001  -60.650002
#           9999        11599 -127.660004 -87.139999   98.919998 -101.410004
#
#                               F7          T3          T5          O1  \
# instances timepoints
# 1         0            65.769997  149.500000   38.090000   37.820000
#           1            42.549999  119.040001   12.320000   13.630000
#           2            41.560001  109.250000    9.220000   12.420000
#           3            83.809998  151.070007   53.660000   56.369999
#           4            75.730003  142.119995   49.840000   52.810001
# ...                          ...         ...         ...         ...
# 2         9995        -87.129997  -41.790001  -77.870003 -137.360001
#           9996        -82.370003  -47.299999  -78.370003 -129.899994
#           9997        -53.520000  -22.360001  -52.980000  -97.040001
#           9998        -80.849998  -59.080002  -93.790001 -131.070007
#           9999       -105.540001  -96.019997 -131.619995 -164.020004
#
#                              Fz  ...         Pz         Fp2         F4  \
# instances timepoints             ...
# 1         0           28.480000  ...  75.519997   76.720001  67.870003
#           1           -3.870000  ...  53.720001   46.950001  44.099998
#           2          -14.040000  ...  41.970001   48.900002  33.180000
#           3           21.530001  ...  89.720001   82.389999  66.529999
#           4            8.940000  ...  94.160004   68.110001  57.950001
# ...                         ...  ...        ...         ...        ...
# 2         9995       -27.820000  ... -13.450000  -69.680000 -32.099998
#           9996       -30.389999  ... -24.170000  -68.099998 -36.570000
#           9997        -4.500000  ...   9.870000  -48.150002  -7.770000
#           9998       -35.169998  ... -21.840000  -81.470001 -29.740000
#           9999       -56.270000  ... -61.590000 -101.260002 -54.610001
#
#                               C4          P4          F8          T4  \
# instances timepoints
# 1         0            21.830000  204.610001  -59.549999  241.250000
#           1            -3.100000  212.619995  -79.680000  225.089996
#           2            -6.840000  162.610001  -88.129997  196.699997
#           3            38.090000  205.720001  -51.060001  241.250000
#           4            35.310001  254.679993  -52.689999  256.089996
# ...                          ...         ...         ...         ...
# 2         9995        -63.790001   22.719999 -118.230003  119.610001
#           9996        -72.809998  -28.790001 -128.770004   85.580002
#           9997        -44.349998   23.590000 -104.160004  114.379997
#           9998        -83.830002   24.430000 -132.429993   79.720001
#           9999       -118.900002  -62.160000 -166.250000   15.350000
#
#                               T6          O2          EKG
# instances timepoints
# 1         0            87.320000  150.979996 -2648.439941
#           1            68.389999  126.430000  2274.139893
#           2            67.419998  120.349998   153.940002
#           3           101.110001  165.110001 -3030.659912
#           4           100.150002  164.940002   404.940002
# ...                          ...         ...          ...
# 2         9995        -80.580002  -73.160004  2372.300049
#           9996        -82.309998  -76.040001   130.539993
#           9997        -70.300003  -49.049999 -2685.510010
#           9998       -112.820000  -84.279999  1606.150024
#           9999       -150.179993 -124.690002  2170.110107
#
# [20000 rows x 21 columns]

# %%
 # Fit HC2
cnn = CNNClassifier()
predictions = cnn.fit(mi_pd, pd.DataFrame([1,2]))

# Predict and print accuracy
# predictions = hc2.predict(x_test)
# print(accuracy_score(y_test, predictions))

# %%
predictions = cnn.predict(mi_pd)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step

# %%
predictions
# Out:
# array([1, 1])

# %%
pq_test = pd.read_parquet("gcs/hms-harmful-brain-activity-classification/train_eegs/463265518.parquet")

# %%
pq_test.shape
# Out:
# (11600, 20)

# %%
pq_test = pd.read_parquet("gcs/hms-harmful-brain-activity-classification/train_eegs/3764624085.parquet")

# %%
pq_test.shape
# Out:
# (10800, 20)

# %%
len(pq_test)
# Out:
# 10800

# %%
middle = (len(pq_test)-10_000)//2
pq_test_middle = pq_test.iloc[middle:middle+10_000]

# %%
pq_test_middle.shape
# Out:
# (10000, 20)

# %%
BASE_PATH = "gcs/hms-harmful-brain-activity-classification/"

df = pd.read_csv(f'{BASE_PATH}/train.csv')
df['eeg_path'] = f'{BASE_PATH}/train_eegs/'+df['eeg_id'].astype(str)+'.parquet'
df['class_name'] = df.expert_consensus.copy()
display(df.head(2))

# Test
test_df = pd.read_csv(f'{BASE_PATH}/test.csv')
test_df['eeg_path'] = f'{BASE_PATH}/test_eegs/'+test_df['eeg_id'].astype(str)+'.parquet'

display(test_df.head(2))
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# 0       42516          Seizure             3         0         0          0
# 1       42516          Seizure             3         0         0          0
#
#    grda_vote  other_vote                                           eeg_path  \
# 0          0           0  gcs/hms-harmful-brain-activity-classification/...
# 1          0           0  gcs/hms-harmful-brain-activity-classification/...
#
#   class_name
# 0    Seizure
# 1    Seizure
#    spectrogram_id      eeg_id  patient_id  \
# 0          853520  3911565283        6885
#
#                                             eeg_path
# 0  gcs/hms-harmful-brain-activity-classification/...
