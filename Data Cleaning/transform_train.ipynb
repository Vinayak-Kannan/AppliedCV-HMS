# %% [markdown]
# This notebook prepares the data for being ran through the EfficientNet DataLoader
# It also performs explaratory EDA to ensure the transformation worked as expected

# %%
import pandas as pd
# Out:
# /var/folders/r9/bzw4rbwd5nb52ddsnf14xsqm0000gn/T/ipykernel_13078/2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head(20)
# Out:
#         eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0   1628180742           0                       0.0          353733
# 1   1628180742           1                       6.0          353733
# 2   1628180742           2                       8.0          353733
# 3   1628180742           3                      18.0          353733
# 4   1628180742           4                      24.0          353733
# 5   1628180742           5                      26.0          353733
# 6   1628180742           6                      30.0          353733
# 7   1628180742           7                      36.0          353733
# 8   1628180742           8                      40.0          353733
# 9   2277392603           0                       0.0          924234
# 10  2277392603           1                       2.0          924234
# 11   722738444           0                       0.0          999431
# 12   722738444           1                       2.0          999431
# ...

# %%
# Find the max of eeg_label_offset_seconds
max = df['eeg_label_offset_seconds'].max()

# %%
# Filter spectogram_id to be equal to 353733
df[df['spectrogram_id'] == 353733]
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
# 5  1628180742           5                      26.0          353733
# 6  1628180742           6                      30.0          353733
# 7  1628180742           7                      36.0          353733
# 8  1628180742           8                      40.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# ...

# %%
# Filter to spectrogram id where the eg_label_offset_seconds is equal to the max
spec_id = df[df['eeg_label_offset_seconds'] == max]['spectrogram_id']
df[df['spectrogram_id'] == spec_id.values[0]]
# Out:
#            eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 69034  2259539799           0                       0.0      1391458063
# 69035  2259539799           1                       2.0      1391458063
# 69036  2259539799           2                      22.0      1391458063
# 69037  2259539799           3                      28.0      1391458063
# 69038  2259539799           4                      30.0      1391458063
# ...           ...         ...                       ...             ...
# 69772  2259539799         738                    3352.0      1391458063
# 69773  2259539799         739                    3362.0      1391458063
# 69774  2259539799         740                    3364.0      1391458063
# 69775  2259539799         741                    3366.0      1391458063
# 69776  2259539799         742                    3372.0      1391458063
#
#        spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# ...

# %%
df[df['eeg_id'] == 2259539799]
# Out:
#            eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 69034  2259539799           0                       0.0      1391458063
# 69035  2259539799           1                       2.0      1391458063
# 69036  2259539799           2                      22.0      1391458063
# 69037  2259539799           3                      28.0      1391458063
# 69038  2259539799           4                      30.0      1391458063
# ...           ...         ...                       ...             ...
# 69772  2259539799         738                    3352.0      1391458063
# 69773  2259539799         739                    3362.0      1391458063
# 69774  2259539799         740                    3364.0      1391458063
# 69775  2259539799         741                    3366.0      1391458063
# 69776  2259539799         742                    3372.0      1391458063
#
#        spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# ...

# %%
# Count the number of speoctrogram_id's where the count of unique expert_consensus is greater than 1
df.groupby('spectrogram_id')['expert_consensus'].nunique().value_counts()

# Add a column which is the count of unique expert_consensus for each spectrogram_id
df['unique_expert_consensus'] = df.groupby('spectrogram_id')['expert_consensus'].transform('nunique')
df
# Out:
#             eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0       1628180742           0                       0.0          353733
# 1       1628180742           1                       6.0          353733
# 2       1628180742           2                       8.0          353733
# 3       1628180742           3                      18.0          353733
# 4       1628180742           4                      24.0          353733
# ...            ...         ...                       ...             ...
# 106795   351917269           6                      12.0      2147388374
# 106796   351917269           7                      14.0      2147388374
# 106797   351917269           8                      16.0      2147388374
# 106798   351917269           9                      18.0      2147388374
# 106799   351917269          10                      20.0      2147388374
#
#         spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# ...

# %%
# Filter df where the unique_expert_consensus is 5
df[df['unique_expert_consensus'] == 5]
# Out:
#             eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 954     2415314690           0                       0.0        13143748
# 955     2415314690           1                       2.0        13143748
# 956      628369060           0                       0.0        13143748
# 957      628369060           1                       4.0        13143748
# 958      628369060           2                      10.0        13143748
# ...            ...         ...                       ...             ...
# 103849  1399237886           4                      38.0      2074135650
# 103850  1399237886           5                      44.0      2074135650
# 103851  1399237886           6                      52.0      2074135650
# 103852  1399237886           7                      62.0      2074135650
# 103853  1399237886           8                      72.0      2074135650
#
#         spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# ...

# %%
# Filter df wehre spectrogram_id is 13143748
df[df['spectrogram_id'] == 13143748]
# Out:
#           eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 954   2415314690           0                       0.0        13143748
# 955   2415314690           1                       2.0        13143748
# 956    628369060           0                       0.0        13143748
# 957    628369060           1                       4.0        13143748
# 958    628369060           2                      10.0        13143748
# ...          ...         ...                       ...             ...
# 1022  3125905615           0                       0.0        13143748
# 1023  3125905615           1                       2.0        13143748
# 1024  3125905615           2                       6.0        13143748
# 1025  3125905615           3                       8.0        13143748
# 1026  3125905615           4                      10.0        13143748
#
#       spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# ...

# %%
max
# Out:
# 3372.0

# %%
spec_id
# Out:
# 69776    1391458063
# Name: spectrogram_id, dtype: int64

# %%
# Create a column that
